# %%
# !mkdir out
# !cp drive/MyDrive/image-generator -r .
# !chmod 755 -R image-generator

# %%
# Fix for a blender issue in colab
import os

os.environ["LD_PRELOAD"] = ""

# !apt update
# !apt remove libtcmalloc-minimal4
# !apt install libtcmalloc-minimal4
os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0"

# !echo $LD_PRELOAD

# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev
# !apt install libglu1-mesa libsm-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,428 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,326 kB]
# ...

# %%
# Install blender
# !wget https://download.blender.org/release/Blender2.91/blender-2.91.2-linux64.tar.xz
# !tar -xf blender-2.91.2-linux64.tar.xz
# !ln -s /content/blender-2.91.2-linux64/blender /usr/local/bin/blender
# !blender-2.91.2-linux64/blender -v
# Out:
# --2021-09-17 19:41:59--  https://download.blender.org/release/Blender2.91/blender-2.91.2-linux64.tar.xz
# Resolving download.blender.org (download.blender.org)... 82.94.213.221
# Connecting to download.blender.org (download.blender.org)|82.94.213.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151604660 (145M) [application/octet-stream]
# Saving to: ‘blender-2.91.2-linux64.tar.xz’
#
# blender-2.91.2-linu 100%[===================>] 144.58M  3.12MB/s    in 48s
#
# 2021-09-17 19:42:47 (2.99 MB/s) - ‘blender-2.91.2-linux64.tar.xz’ saved [151604660/151604660]
#
# Blender 2.91.2
# 	build date: 2021-01-19
# 	build time: 16:16:34
# 	build commit date: 2021-01-19
# 	build commit time: 16:15
# 	build hash: 5be9ef417703
# 	build platform: Linux
# 	build type: Release
# ...

# %%
# Install everything for a virtual display (workaround for a blender issue)
# !apt-get install x11-utils > /dev/null 2>&1 
# !pip install pyglet > /dev/null 2>&1 
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
# Set up virtual display
from IPython import display as ipythondisplay

from pyvirtualdisplay import Display
display = Display(visible = 0, size = (400, 300))
display.start()

# %%
# !python image-generator/main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Fra:1 Mem:715.62M (Peak 715.64M) | Time:00:00.21 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Plane
# Fra:1 Mem:715.62M (Peak 715.64M) | Time:00:00.21 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Cube
# Fra:1 Mem:750.90M (Peak 750.90M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:1 Mem:718.35M (Peak 750.90M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Waiting for render to start
# Fra:1 Mem:718.35M (Peak 750.90M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:718.35M (Peak 750.90M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Scene
# Fra:1 Mem:718.35M (Peak 750.90M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Shaders
# ...

# %%
from google.colab import files

# !zip -r out.zip out
files.download("out.zip")
# Out:
#   adding: out/ (stored 0%)
#   adding: out/index.csv (deflated 88%)
#   adding: out/imgs/ (stored 0%)
#   adding: out/imgs/6450.png (deflated 0%)
#   adding: out/imgs/6526.png (deflated 0%)
#   adding: out/imgs/6393.png (deflated 0%)
#   adding: out/imgs/6468.png (deflated 0%)
#   adding: out/imgs/6543.png (deflated 0%)
#   adding: out/imgs/6429.png (deflated 0%)
#   adding: out/imgs/6384.png (deflated 0%)
#   adding: out/imgs/6546.png (deflated 0%)
#   adding: out/imgs/6436.png (deflated 0%)
#   adding: out/imgs/6420.png (deflated 0%)
#   adding: out/imgs/6582.png (deflated 0%)
#   adding: out/imgs/6471.png (deflated 0%)
#   adding: out/imgs/6518.png (deflated 0%)
#   adding: out/imgs/6485.png (deflated 0%)
#   adding: out/imgs/6484.png (deflated 0%)
#   adding: out/imgs/6549.png (deflated 0%)
#   adding: out/imgs/6433.png (deflated 0%)
#   adding: out/imgs/6459.png (deflated 0%)
#   adding: out/imgs/6508.png (deflated 0%)
#   adding: out/imgs/6562.png (deflated 0%)
# ...

# %%
# !rm out -r
# !rm out.zip
# !mkdir out
